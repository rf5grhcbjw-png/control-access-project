# %%
class DriverException(Exception):
    pass
people = [('James, 17'), ('Kirk, 9'), ('Lars, 13'), ('Robert, 8')]
driver = None
age = 18
for p in people: 
    if  age >= 18: 
        driver = (people, age)
        break 
    else: 
        raise DriverException('Driver not found')

# %%
note_1 = float(input('first note:'))
note_2 = float(input('Second note:'))
note_3 = float(input('Third note: '))
note_4 = float(input(' Fourth note: '))

average = (note_1 + note_2 + note_3 + note_4) / 4 
print(f'average {average}')

if average >= 7:
    print('You pass')
elif average >= 5:
    print('You have to retake the exam')
elif average <= 5: 
    print("You fail")
else: 
    print('You are reproved')
# Out:
# average 0.0
# You fail

# %%
# This is a project to control users for reception using a reading mechanism through digital biometrics. 

list_residents = ['user 1', 'user 2', 'user 3']
for index, list_residents in enumerate(list_residents):
    print(f'{index}: {list_residents}')

list_visitants = ['visitant 1', 'visitant 2', 'visitant 3']
for index, list_residents in enumerate(list_residents):
    print(f'{index}: {list_residents}')
# Out:
# 0: user 1
# 1: user 2
# 2: user 3
# 0: u
# 1: s
# 2: e
# 3: r
# 4:
# 5: 3
